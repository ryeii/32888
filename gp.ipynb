# %%
import sinergym
from sinergym.utils.callbacks import LoggerEvalCallback
from sinergym.utils.rewards import *
from sinergym.utils.wrappers import LoggerWrapper
from datetime import datetime
import gym
import numpy as np
import gpytorch
import pandas as pd


environment = "Eplus-demo-v1"
episodes = 1
experiment_date = datetime.today().strftime('%Y-%m-%d %H:%M')

# register run name
name = F"DQN-{environment}-episodes_{episodes}({experiment_date})"


extra_conf={
    'timesteps_per_hour':4,
    'runperiod':(1,1,1991,2,1,1993),
}
env = gym.make(environment, 
                reward=LinearReward, 
                config_params=extra_conf)


env = LoggerWrapper(env)

data = pd.DataFrame()

print(env.action_space)

for i in range(100):
    print(env.action_space.sample())

print(env.action_mapping)

# obs = env.reset()
# for timestep in range(1, 100000):
#     action = env.action_space.sample()
#     obs, reward, done, info = env.step(action)
#     # print(obs)
#     if done:
#         env.reset()


env.close()
# Out:
# [2023-04-09 01:31:35,353] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-04-09 01:31:35,353] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-04-09 01:31:35,353] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-04-09 01:31:35,353] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-04-09 01:31:35,353] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf ExternalInterface object if it is not present...
# [2023-04-09 01:31:35,356] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-04-09 01:31:35,356] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-04-09 01:31:35,356] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-04-09 01:31:35,356] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-04-09 01:31:35,356] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-04-09 01:31:35,362] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-04-09 01:31:35,362] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-04-09 01:31:35,362] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-04-09 01:31:35,362] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-04-09 01:31:35,362] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Updating idf OutPut:Variable and variables XML tree model for BVCTB connection.
# [2023-04-09 01:31:35,366] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-04-09 01:31:35,366] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-04-09 01:31:35,366] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-04-09 01:31:35,366] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-04-09 01:31:35,366] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-04-09 01:31:35,369] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-04-09 01:31:35,369] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-04-09 01:31:35,369] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-04-09 01:31:35,369] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# [2023-04-09 01:31:35,369] EPLUS_ENV_demo-v1_MainThread_ROOT INFO:Setting up action definition in building model if exists...
# Discrete(10)
# 1
# 9
# 6
# 5
# 9
# 6
# 2
# 2
# 2
# 4
# 9
# 8
# 3
# 6
# 1
# 1
# 9
# 3
# 1
# 8
# 1
# 6
# 8
# 9
# 9
# 9
# 6
# 4
# 5
# 2
# 6
# 2
# 9
# 3
# 9
# 1
# 6
# 2
# 7
# 3
# 5
# 1
# 5
# 0
# 0
# 0
# 9
# 9
# 7
# 0
# 2
# 2
# 4
# 7
# 8
# 1
# 9
# 9
# 9
# 8
# 7
# 3
# 5
# 5
# 2
# 8
# 6
# 3
# 1
# 1
# 1
# 4
# 0
# 7
# 2
# 0
# 5
# 0
# 6
# 3
# 2
# 2
# 9
# 3
# 2
# 9
# 9
# 4
# 2
# 0
# 4
# 4
# 7
# 1
# 1
# 3
# 3
# 5
# 0
# 0
# {0: (15, 30), 1: (16, 29), 2: (17, 28), 3: (18, 27), 4: (19, 26), 5: (20, 25), 6: (21, 24), 7: (22, 23), 8: (22, 22), 9: (21, 21)}
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 49
#      38 print(env.action_mapping)
#      40 # obs = env.reset()
#      41 # for timestep in range(1, 100000):
#      42 #     action = env.action_space.sample()
#    (...)
#      45 #     if done:
#      46 #         env.reset()
# ---> 49 env.close()
#
# File /workspaces/sinergym-475112771eb968ca05ea2e27c16fed29e37cb9fe/sinergym/utils/wrappers.py:278, in LoggerWrapper.close(self)
#     275 # Record last episode summary before end simulation
#     276 self.env.simulator.logger_main.debug(
#     277     'End of episode, recording summary (progress.csv) if logger is active')
# --> 278 self.logger.log_episode(episode=self.env.simulator._epi_num)
#     280 # Then, close env
#     281 self.env.close()
#
# File /workspaces/sinergym-475112771eb968ca05ea2e27c16fed29e37cb9fe/sinergym/utils/logger.py:252, in CSVLogger.log_episode(self, episode)
#     249     comfort_violation = np.nan
#     251 # write steps_info in monitor.csv
# --> 252 with open(self.log_file, 'w', newline='') as file_obj:
#     253     # Create a writer object from csv module
#     254     csv_writer = csv.writer(file_obj)
#     255     # Add contents of list as last row in the csv file
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
class MyGP(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super().__init__(train_x, train_y, likelihood)

        # Mean Function
        self.mean_module = gpytorch.means.ZeroMean()

        # Kernel Function
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())

    def forward(self, x):
        mean = self.mean_module(x)
        covar = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean, covar)

# train_x = ...; train_y = ...
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = MyGP(train_x, train_y, likelihood)


# Put model in train mode
model.train()
likelihood.train()

# Define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.1)

# Define loss function the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

# training step
for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(train_x)
    # Calc loss
    loss = -mll(output, train_y)
    #  backprop gradients
    loss.backward()
    print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))
    optimizer.step()
